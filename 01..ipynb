# %%
import pandas as pd

# %%
df_2018 = pd.read_excel("data/2018-v268-06102022-EU MRV Publication of information.xlsx",header=2)
# Out:
# /Users/emmanuelsekyi/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df_2018.head()
# Out:
#    IMO Number           Name         Ship type  Reporting Period   Technical efficiency Port of Registry Home Port Ice Class DoC issue date DoC expiry date Verifier Number                                 Verifier Name                          Verifier NAB                              Verifier Address           Verifier City Verifier Accreditation number Verifier Country    A    B    C   D  Total fuel consumption [m tonnes]  Fuel consumptions assigned to On laden [m tonnes]  Total CO₂ emissions [m tonnes]  CO₂ emissions from all voyages between ports under a MS jurisdiction [m tonnes]  CO₂ emissions from all voyages which departed from ports under a MS jurisdiction [m tonnes]  CO₂ emissions from all voyages to ports under a MS jurisdiction [m tonnes]  CO₂ emissions which occurred within ports under a MS jurisdiction at berth [m tonnes]  CO₂ emissions assigned to Passenger transport [m tonnes]  CO₂ emissions assigned to Freight transport [m tonnes]  CO₂ emissions assigned to On laden [
# ...

# %%
df_2019 = pd.read_excel("data/2019-v213-24042023-EU MRV Publication of information.xlsx",header=2)
# Out:
# /Users/emmanuelsekyi/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df_2019.head()
# Out:
#    IMO Number           Name         Ship type  Reporting Period    Technical efficiency Port of Registry Home Port Ice Class DoC issue date DoC expiry date Verifier Number                                 Verifier Name                          Verifier NAB                              Verifier Address           Verifier City Verifier Accreditation number Verifier Country    A    B    C    D  Total fuel consumption [m tonnes]  Fuel consumptions assigned to On laden [m tonnes]  Total CO₂ emissions [m tonnes]  CO₂ emissions from all voyages between ports under a MS jurisdiction [m tonnes]  CO₂ emissions from all voyages which departed from ports under a MS jurisdiction [m tonnes]  CO₂ emissions from all voyages to ports under a MS jurisdiction [m tonnes]  CO₂ emissions which occurred within ports under a MS jurisdiction at berth [m tonnes]  CO₂ emissions assigned to Passenger transport [m tonnes]  CO₂ emissions assigned to Freight transport [m tonnes]  CO₂ emissions assigned to On laden
# ...

# %%
df_2020 = pd.read_excel("data/2020-v184-24042023-EU MRV Publication of information.xlsx",header=2)
# Out:
# /Users/emmanuelsekyi/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df_2020.head(2)
# Out:
#    IMO Number           Name         Ship type  Reporting Period   Technical efficiency Port of Registry Home Port Ice Class DoC issue date DoC expiry date Verifier Number                        Verifier Name                   Verifier NAB                              Verifier Address           Verifier City Verifier Accreditation number Verifier Country    A    B    C    D  Total fuel consumption [m tonnes]  Fuel consumptions assigned to On laden [m tonnes]  Total CO₂ emissions [m tonnes]  CO₂ emissions from all voyages between ports under a MS jurisdiction [m tonnes]  CO₂ emissions from all voyages which departed from ports under a MS jurisdiction [m tonnes]  CO₂ emissions from all voyages to ports under a MS jurisdiction [m tonnes]  CO₂ emissions which occurred within ports under a MS jurisdiction at berth [m tonnes]  CO₂ emissions assigned to Passenger transport [m tonnes]  CO₂ emissions assigned to Freight transport [m tonnes]  CO₂ emissions assigned to On laden [m tonnes]  Annu
# ...

# %%
df_2021 = pd.read_excel("data/2021-v146-01052023-EU MRV Publication of information.xlsx",header=2)
# Out:
# /Users/emmanuelsekyi/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df_2021.head()
# Out:
#    IMO Number         Name         Ship type  Reporting Period   Technical efficiency Port of Registry  Home Port Ice Class DoC issue date DoC expiry date Verifier Number              Verifier Name                   Verifier NAB                    Verifier Address Verifier City Verifier Accreditation number Verifier Country    A    B    C    D  Total fuel consumption [m tonnes]  Fuel consumptions assigned to On laden [m tonnes]  Total CO₂ emissions [m tonnes]  CO₂ emissions from all voyages between ports under a MS jurisdiction [m tonnes]  CO₂ emissions from all voyages which departed from ports under a MS jurisdiction [m tonnes]  CO₂ emissions from all voyages to ports under a MS jurisdiction [m tonnes]  CO₂ emissions which occurred within ports under a MS jurisdiction at berth [m tonnes]  CO₂ emissions assigned to Passenger transport [m tonnes]  CO₂ emissions assigned to Freight transport [m tonnes]  CO₂ emissions assigned to On laden [m tonnes]  Annual Time spent at sea [hours] An
# ...

# %%
df_2018.columns
# Out:
# Index(['IMO Number', 'Name', 'Ship type', 'Reporting Period',
#        'Technical efficiency', 'Port of Registry', 'Home Port', 'Ice Class',
#        'DoC issue date', 'DoC expiry date', 'Verifier Number', 'Verifier Name',
#        'Verifier NAB', 'Verifier Address', 'Verifier City',
#        'Verifier Accreditation number', 'Verifier Country', 'A', 'B', 'C', 'D',
#        'Total fuel consumption [m tonnes]',
#        'Fuel consumptions assigned to On laden [m tonnes]',
#        'Total CO₂ emissions [m tonnes]',
#        'CO₂ emissions from all voyages between ports under a MS jurisdiction [m tonnes]',
#        'CO₂ emissions from all voyages which departed from ports under a MS jurisdiction [m tonnes]',
#        'CO₂ emissions from all voyages to ports under a MS jurisdiction [m tonnes]',
#        'CO₂ emissions which occurred within ports under a MS jurisdiction at berth [m tonnes]',
#        'CO₂ emissions assigned to Passenger transport [m tonnes]',
# ...

# %%
df_2021["Ship type"].unique()
# Out:
# array(['Other ship types', 'Ro-pax ship', 'Ro-ro ship', 'Bulk carrier',
#        'Passenger ship', 'General cargo ship', 'Chemical tanker',
#        'Container ship', 'Refrigerated cargo carrier', 'Vehicle carrier',
#        'Gas carrier', 'Container/ro-ro cargo ship', 'Oil tanker',
#        'Combination carrier', 'LNG carrier'], dtype=object)

# %%
import glob

# %%
files = glob.glob('data/*.xlsx')

# %%
dfs_files = [pd.read_excel(f,header=2) for f in files]
# Out:
# /Users/emmanuelsekyi/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/emmanuelsekyi/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/emmanuelsekyi/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/emmanuelsekyi/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df = pd.concat(dfs_files, ignore_index=True)

# %%
df.columns
# Out:
# Index(['IMO Number', 'Name', 'Ship type', 'Reporting Period',
#        'Technical efficiency', 'Port of Registry', 'Home Port', 'Ice Class',
#        'DoC issue date', 'DoC expiry date', 'Verifier Number', 'Verifier Name',
#        'Verifier NAB', 'Verifier Address', 'Verifier City',
#        'Verifier Accreditation number', 'Verifier Country', 'A', 'B', 'C', 'D',
#        'Total fuel consumption [m tonnes]',
#        'Fuel consumptions assigned to On laden [m tonnes]',
#        'Total CO₂ emissions [m tonnes]',
#        'CO₂ emissions from all voyages between ports under a MS jurisdiction [m tonnes]',
#        'CO₂ emissions from all voyages which departed from ports under a MS jurisdiction [m tonnes]',
#        'CO₂ emissions from all voyages to ports under a MS jurisdiction [m tonnes]',
#        'CO₂ emissions which occurred within ports under a MS jurisdiction at berth [m tonnes]',
#        'CO₂ emissions assigned to Passenger transport [m tonnes]',
# ...

# %%
df.isna().sum()
# Out:
# IMO Number                                                                                                                     0
# Name                                                                                                                           0
# Ship type                                                                                                                      0
# Reporting Period                                                                                                               0
# Technical efficiency                                                                                                        1697
#                                                                                                                            ...
# CO₂ emissions per transport work (freight) on laden voyages [g CO₂ / m tonnes · n miles]                                   48946
# ...

# %%
null_values_percentage = (df.isna().sum() / len(df)) * 100

# %%
null_values_percentage_df = pd.DataFrame(null_values_percentage, columns=['Missing Percentage'])

# %%
null_values_percentage_df
# Out:
#                                                     Missing Percentage
# IMO Number                                                    0.000000
# Name                                                          0.000000
# Ship type                                                     0.000000
# Reporting Period                                              0.000000
# Technical efficiency                                          3.467086
# ...                                                                ...
# CO₂ emissions per transport work (freight) on l...          100.000000
# Additional information to facilitate the unders...           99.805909
# Average density of the cargo transported [m ton...           99.989785
# Annual Total time spent at sea [hours]                       49.628162
# Total time spent at sea [hours]                              49.628162
#
# [63 rows x 1 columns]

# %%
sorted_null_values_percentage_df = null_values_percentage_df.sort_values(by='Missing Percentage', ascending=False)

# %%
sorted_null_values_percentage_df.head(50)
# Out:
#                                                     Missing Percentage
# CO₂ emissions per transport work (freight) on l...          100.000000
# Fuel consumption per transport work (freight) o...          100.000000
# Average density of the cargo transported [m ton...           99.989785
# D                                                            99.987742
# Fuel consumption per transport work (pax) on la...           99.965268
# CO₂ emissions per transport work (pax) on laden...           99.965268
# Additional information to facilitate the unders...           99.805909
# Fuel consumption per transport work (volume) on...           99.595473
# CO₂ emissions per transport work (volume) on la...           99.595473
# Fuel consumption per transport work (dwt) on la...           99.039758
# CO₂ emissions per transport work (dwt) on laden...           99.039758
# Annual average CO₂ emissions per transport work...           97.346055
# ...

# %%
def calculate_missing_percentage(df):
    return (df.isna().sum() / len(df)) * 100

def missing_percentage_dataframe(df):
    missing_percentage = calculate_missing_percentage(df)
    return pd.DataFrame(missing_percentage, columns=['Missing Percentage'])

def sort_by_missing_percentage(df):
    return df.sort_values(by='Missing Percentage', ascending=False)

# %%
missing_percentage_df = missing_percentage_dataframe(df)
sorted_missing_percentage_df = sort_by_missing_percentage(missing_percentage_df)
sorted_missing_percentage_df
# Out:
#                                                     Missing Percentage
# CO₂ emissions per transport work (freight) on l...          100.000000
# Fuel consumption per transport work (freight) o...          100.000000
# Average density of the cargo transported [m ton...           99.989785
# D                                                            99.987742
# Fuel consumption per transport work (pax) on la...           99.965268
# ...                                                                ...
# CO₂ emissions from all voyages to ports under a...            0.000000
# CO₂ emissions which occurred within ports under...            0.000000
# Name                                                          0.000000
# Annual average Fuel consumption per distance [k...            0.000000
# IMO Number                                                    0.000000
#
# [63 rows x 1 columns]

# %%
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.expand_frame_repr', False)  # Prevent wrapping to multiple lines
pd.set_option('display.max_rows', None)  # Show all rows

# %%
sorted_missing_percentage_df
# Out:
#                                                     Missing Percentage
# CO₂ emissions per transport work (freight) on l...          100.000000
# Fuel consumption per transport work (freight) o...          100.000000
# Average density of the cargo transported [m ton...           99.989785
# D                                                            99.987742
# Fuel consumption per transport work (pax) on la...           99.965268
# CO₂ emissions per transport work (pax) on laden...           99.965268
# Additional information to facilitate the unders...           99.805909
# Fuel consumption per transport work (volume) on...           99.595473
# CO₂ emissions per transport work (volume) on la...           99.595473
# Fuel consumption per transport work (dwt) on la...           99.039758
# CO₂ emissions per transport work (dwt) on laden...           99.039758
# Annual average CO₂ emissions per transport work...           97.346055
# ...

# %%
def drop_columns_above_threshold(original_df, missing_percentage_df, threshold):
    columns_to_drop = missing_percentage_df[missing_percentage_df['Missing Percentage'] > threshold].index
    return original_df.drop(columns=columns_to_drop)

# %%
df = drop_columns_above_threshold()
