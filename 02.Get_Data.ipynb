# %%
import pandas as pd
from pathlib import Path

def get_xlsx_files(folder_path):
    return [file for file in folder_path.iterdir() if file.suffix == '.xlsx']

def read_and_combine_xlsx_files(xlsx_files, header):
    dfs = []

    for file in xlsx_files:
        temp_df = pd.read_excel(file, header=header)
        dfs.append(temp_df)

    combined_df = pd.concat(dfs, ignore_index=True)
    return combined_df

def load_data(folder_path):
    folder_path = Path(folder_path)
    xlsx_files = get_xlsx_files(folder_path)
    combined_df = read_and_combine_xlsx_files(xlsx_files, header=2)
    return combined_df

# %%
data_path = "data/"

# %%
df = load_data(data_path)
# Out:
# /Users/emmanuelsekyi/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/emmanuelsekyi/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/emmanuelsekyi/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/emmanuelsekyi/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df.head()
# Out:
#    IMO Number           Name         Ship type  Reporting Period  \
# 0     6602898  OCEAN MAJESTY    Passenger ship              2020
# 1     6703343       EQUALITY  Other ship types              2020
# 2     7037806    IONIAN STAR       Ro-pax ship              2020
# 3     7043843          TALOS        Ro-ro ship              2020
# 4     7128332       SEA WIND       Ro-pax ship              2020
#
#     Technical efficiency Port of Registry Home Port Ice Class DoC issue date  \
# 0  EIV (31.73 gCO₂/t·nm)          Madeira       NaN       NaN     01/07/2021
# 1  EIV (57.84 gCO₂/t·nm)           Beirut       NaN       NaN     30/06/2021
# 2   EIV (19.4 gCO₂/t·nm)              NaN       NaN       NaN     31/03/2021
# 3  EIV (48.71 gCO₂/t·nm)          Piraeus   Piraeus       NaN     16/06/2021
# 4   EIV (9.29 gCO₂/t·nm)          Tallinn   Tallinn        IB     26/04/2021
#
#   DoC expiry date  ...  \
# 0      30/06/2022  ...
# 1      30/06/2022  ...
# 2      30/06/2022  ...
# ...

# %%
from scripts.load_data import load_data

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
df = load_data(data_path)
# Out:
# 2023-05-03 04:35:57,474 - INFO - Found 4 .xlsx files in data
# 2023-05-03 04:35:57,476 - INFO - Reading data/2020-v184-24042023-EU MRV Publication of information.xlsx
# /Users/emmanuelsekyi/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2023-05-03 04:36:04,876 - INFO - Reading data/2018-v268-06102022-EU MRV Publication of information.xlsx
# /Users/emmanuelsekyi/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2023-05-03 04:36:12,283 - INFO - Reading data/2019-v213-24042023-EU MRV Publication of information.xlsx
# ...

# %%
df
